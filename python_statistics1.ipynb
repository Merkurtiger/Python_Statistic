# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns


xs=np.linspace(0,9,100)

ys=np.sin(xs)

sns.set_style("darkgrid")
sns.set_context("poster")

plt.title("Sinus Wave")

plt.plot(xs,ys, label="Sinus")
plt.legend()

#plt.show()
